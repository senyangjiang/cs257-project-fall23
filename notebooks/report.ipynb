# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
l1: 32, l2: 16:
Baseline: 52.76% (10.05%)
l1: 32, l2: 8:
Baseline: 47.13% (10.07%)
l1: 32, l2: 4:
Baseline: 50.79% (7.07%)
l1: 16, l2: 16:
Baseline: 50.79% (11.10%)
l1: 16, l2: 8:
Baseline: 43.55% (9.62%)
l1: 16, l2: 4:
Baseline: 44.71% (7.61%)
l1: 8, l2: 8:
Baseline: 44.63% (10.49%)
l1: 8, l2: 4:
Baseline: 43.13% (8.52%)
l1: 4, l2: 4:
Baseline: 45.68% (11.55%)

# %%
# creating the dataset
data = {'(32,16)':48.85, '(32,18)':45.51, '(32,4)':51.22,
        '(16,16)':51.28, '(16,8)':51.09, '(16,4)':51.15,
        '(8,8)':52.76, '(8,4)':51.22,
        '(4,4)':50.45}
sizes = np.array(list(data.keys()))
values = np.array(list(data.values())) / 100

fig = plt.figure()

# creating the bar plot
plt.bar(sizes, values,
        width = 0.4)

plt.xlabel("(layer1 # nodes, layer2 # nodes)")
plt.ylabel("Accuracy")
plt.title("model accuracy of different layer sizes")
plt.show()
