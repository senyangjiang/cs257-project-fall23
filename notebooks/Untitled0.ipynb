# %%
>>> import pandas as pd
>>> a = pd.read_csv("output copy.csv", index_col=0)
>>> b = pd.read_csv("output.csv", index_col=0)
>>> c = pd.concat([a, b], axis=0)
>>> c.to_csv("output_500.csv")
>>> c.to_csv("ooutput_500.csv", index=False)
>>> c.drop(columns=["result(kissat+'')","time(kissat+'')"])
>>> c = c.drop(columns=["result(kissat+'')","time(kissat+'')"])
>>> c.to_csv("ooutput_500.csv", index=False)
